# %%
suppressPackageStartupMessages({
    library(openxlsx)
    library(clusterProfiler)
})

# %% [markdown]
# Obtain cell type markers from text files.

# %%
txt.files <- list.files(pattern = ".txt", path = "RA1", full.names = T)
meta_data <- strsplit(txt.files, split = "_")

celltypes <- c("b-cells", "cd4-tcells", "cd8-tcells", "dendritic-cells", "fibro1-cd55", "fibro2a-thy1",
              "fibro2b-thy1", "macrophage", "mast-cells", "nk-cells", "plasma-cells", "platelets", "tph-cells")

GeneSets <- setNames(lapply(txt.files, function(cell.type.file) {
    read.table(cell.type.file, header = T, stringsAsFactors = F)$x
}), nm = celltypes)
    
GeneSets
# Out:
# $`b-cells`
# [1] "CD79B"  "LTB"    "CD52"   "CD79A"  "CD37"   "BIRC3"  "MS4A1"  "MEF2C"
# [9] "POU2F2"
#
# $`cd4-tcells`
# [1] "CD52"  "LTB"   "ETS1"  "BIRC3" "IL7R"  "FYB"   "RPS29"
#
# $`cd8-tcells`
#  [1] "CD52"   "CD3D"   "CORO1A" "CD2"    "CXCR4"  "CCL5"   "IL32"   "LCP1"
#  [9] "GZMA"   "HCST"   "GZMK"   "ITGAL"  "NKG7"   "PTPRC"  "TMSB4X"
#
# $`dendritic-cells`
#  [1] "CD74"    "AIF1"    "GPX1"    "MS4A6A"  "CPVL"    "LYZ"     "CTSH"
#  [8] "FCGR2B"  "LST1"    "PLEK"    "CIITA"   "RASSF4"  "CCDC88A" "SAMHD1"
# [15] "PLEKHO1" "TYROBP"
#
# $`fibro1-cd55`
#  [1] "FN1"     "MMP3"    "HTRA1"   "MMP1"    "CRTAC1"  "CLU"     "IGFBP5"
#  [8] "PRG4"    "ITGBL1"  "ITGB8"   "CSN1S1"  "ERRFI1"  "CYP1B1"  "CREB5"
# [15] "SCARA5"  "SEMA3C"  "THBS4"   "CAV1"    "SEMA5A"  "TIMP3"   "SPARCL1"
# [22] "TNFAIP6"
#
# $`fibro2a-thy1`
#  [1] "COL6A3"   "COL1A2"   "COL3A1"   "IGFBP7"   "DCN"      "COL1A1"
#  [7] "AEBP1"    "BGN"      "FBLN1"    "COL6A1"   "SPARC"    "COL5A2"
# [13] "C3"       "COL5A1"   "FBN1"     "LOXL2"    "TAGLN"    "DPT"
# [19] "SERPINF1" "MXRA5"    "TNC"      "THY1"
#
# $`fibro2b-thy1`
#  [1] "C1R"     "CXCL12"  "DCN"     "EFEMP1"  "APOE"    "COL1A2"  "IGFBP4"
#  [8] "CTGF"    "COL14A1" "C3"      "BGN"     "COL6A1"  "VCAN"    "COL6A2"
# [15] "AEBP1"   "CHI3L2"  "COL6A3"  "MMP2"    "CHI3L1"  "CP"      "LUM"
# [22] "DPT"     "PTGDS"   "WISP2"
#
# $macrophage
#  [1] "FTL"      "C1QB"     "CTSB"     "C1QA"     "MARCO"    "RNASE1"
#  [7] "CD68"     "CD14"     "FCGR3A"   "S100A8"   "GRN"      "C1QC"
# [13] "PSAP"     "CTSZ"     "LAPTM5"   "CYBB"     "CTSD"     "AIF1"
# [19] "GLUL"     "A2M"      "S100A9"   "STAB1"    "CD163"    "CTSS"
# [25] "TYROBP"   "FCER1G"   "TYMP"     "MSR1"     "SIGLEC1"  "ACP5"
# [31] "LYZ"      "FCGR2B"   "GPNMB"    "MS4A6A"   "LGMN"     "LTA4H"
# [37] "SDC3"     "C3AR1"    "MAFB"     "ALDH2"    "RASSF4"   "SERPINA1"
# [43] "CPVL"     "CTSH"     "SLCO2B1"  "MS4A4A"   "ATP1B3"   "VAMP8"
# [49] "MS4A7"    "VSIG4"
#
# $`mast-cells`
# [1] "BIRC3"  "NFKBIA" "BMP2K"  "BTG2"   "CSF1"   "IER2"   "LMO4"   "SRGN"
#
# $`nk-cells`
# [1] "GZMA"  "CCL5"  "ITGAX" "NKG7"
#
# $`plasma-cells`
#  [1] "IGLL1"   "IGLL5"   "CD79A"   "MZB1"    "DERL3"   "PIM2"    "SSR4"
#  [8] "SDC1"    "HERPUD1" "SLAMF7"  "ITM2C"   "SPCS3"   "SDF2L1"  "HSP90B1"
# [15] "XBP1"
#
# $platelets
#  [1] "IGFBP7"  "COL4A2"  "HSPG2"   "A2M"     "COL18A1" "COL4A1"  "ENG"
#  [8] "CRIP2"   "SPARCL1" "SPTBN1"  "CD59"    "FKBP1A"  "NFIB"    "PRCP"
# [15] "RAMP3"   "TCF4"    "VWF"     "UACA"
#
# $`tph-cells`
#  [1] "CXCL13" "CD3D"   "CD2"    "ETS1"   "IL32"   "BIRC3"  "IL2RG"  "IL7R"
#  [9] "LTB"    "PTPRC"  "SLA"    "FKBP5"  "MAF"    "SRGN"

# %% [markdown]
# # Run GO on celltype markers
#
# We use the enricher() function from the [clusterProfiler](https://bioconductor.org/packages/release/bioc/html/clusterProfiler.html) R package to perform GO enrichment analysis. The gene annotations were obtained from the [MSigDb](http://software.broadinstitute.org/gsea/msigdb/collections.jsp) (GO Bological Processes dataset). Only terms with an adjusted p-value of >= 0.05 were retuerned.

# %%
h <- suppressPackageStartupMessages({read.gmt("c5.bp.v6.2.symbols.gmt")})

bp.eriched.terms <- setNames(lapply(celltypes, function(cl) {
    egmt <- enricher(GeneSets[[cl]], TERM2GENE = h, pvalueCutoff = 0.05)
    as.data.frame(egmt)
}), nm = celltypes)

# %% [markdown]
# Export results to excel file

# %%
library(openxlsx)

sh <- createWorkbook(title = "RA celltypes GO enrcihment")

for (cl in celltypes) {
    addWorksheet(wb = sh, sheetName = cl)
    firstrow <- paste0("RA1 cluster: ", gsub(pattern = "Cluster", replacement = "", x = cl))
    writeData(wb = sh, x = firstrow, sheet = cl)
    secondrow <- paste0("marker genes: ", paste(GeneSets[[cl]], collapse = ", "))
    writeData(wb = sh, x = secondrow, sheet = cl, startRow = 2)
    writeData(wb = sh, x = "", sheet = cl, startRow = 3)
    writeData(wb = sh, x = bp.eriched.terms[[cl]][, -1], sheet = cl, startRow = 4)
    setColWidths(wb = sh, sheet = cl, cols = 1:ncol(bp.eriched.terms[[cl]]), widths = "auto")
}

saveWorkbook(sh, file = "RA1_cells_clusters_GO_enrichment.xlsx", overwrite = TRUE)

# %% [markdown]
# # Date

# %%
date()
# Out:
# [1] "Mon Jun 10 09:56:49 2019"

# %% [markdown]
# # Session Info

# %%
sessionInfo()
# Out:
# R version 3.5.1 (2018-07-02)
# Platform: x86_64-apple-darwin15.6.0 (64-bit)
# Running under: macOS  10.14.5
#
# Matrix products: default
# BLAS: /Library/Frameworks/R.framework/Versions/3.5/Resources/lib/libRblas.0.dylib
# LAPACK: /Library/Frameworks/R.framework/Versions/3.5/Resources/lib/libRlapack.dylib
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# attached base packages:
# [1] stats4    parallel  stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] GSEABase_1.42.0       graph_1.58.0          annotate_1.58.0
#  [4] XML_3.98-1.13         AnnotationDbi_1.44.0  IRanges_2.14.10
#  [7] S4Vectors_0.18.3      Biobase_2.40.0        BiocGenerics_0.26.0
# [10] clusterProfiler_3.8.1 openxlsx_4.1.0
#
# loaded via a namespace (and not attached):
#  [1] viridis_0.5.1        tidyr_0.8.2          viridisLite_0.3.0
#  [4] bit64_0.9-7          jsonlite_1.6         splines_3.5.1
#  [7] ggraph_1.0.2         assertthat_0.2.0     DO.db_2.9
# [10] rvcheck_0.1.0        blob_1.1.1           ggrepel_0.8.0
# [13] pillar_1.3.1         RSQLite_2.1.1        lattice_0.20-38
# [16] glue_1.3.0           uuid_0.1-2           digest_0.6.18
# [19] qvalue_2.12.0        colorspace_1.4-0     cowplot_0.9.3
# [22] htmltools_0.3.6      Matrix_1.2-14        plyr_1.8.4
# [25] pkgconfig_2.0.2      xtable_1.8-3         purrr_0.3.0
# [28] GO.db_3.7.0          scales_1.0.0         tweenr_0.1.5
# [31] enrichplot_1.0.2     BiocParallel_1.14.2  ggforce_0.1.3
# [34] tibble_2.0.1         ggplot2_3.1.0        UpSetR_1.3.3
# [37] repr_0.15.0          lazyeval_0.2.1       magrittr_1.5
# [40] crayon_1.3.4         memoise_1.1.0        DOSE_3.6.1
# [43] evaluate_0.11        MASS_7.3-50          tools_3.5.1
# [46] data.table_1.12.0    stringr_1.3.1        munsell_0.5.0
# [49] zip_1.0.0            bindrcpp_0.2.2       compiler_3.5.1
# [52] rlang_0.3.1          RCurl_1.95-4.11      ggridges_0.5.0
# [55] units_0.6-0          grid_3.5.1           pbdZMQ_0.3-3
# [58] IRkernel_0.8.12.9000 igraph_1.2.2         bitops_1.0-6
# [61] base64enc_0.1-3      gtable_0.2.0         DBI_1.0.0
# [64] reshape2_1.4.3       R6_2.3.0             gridExtra_2.3
# [67] dplyr_0.7.8          bit_1.1-14           bindr_0.1.1
# [70] fastmatch_1.1-0      fgsea_1.6.0          GOSemSim_2.6.2
# [73] stringi_1.2.4        IRdisplay_0.5.0      Rcpp_1.0.0
# [76] tidyselect_0.2.5
